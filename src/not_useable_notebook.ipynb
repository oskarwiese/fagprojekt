# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import torch
import torch.nn as nn
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier
import GPyOpt
s = 1

# %% [markdown]
# # Data Visualization and Pre-processing

# %%
#data = pd.read_csv("/home/oskar/Desktop/fagprojekt/compas/compas-scores-raw.csv")
#url = "https://raw.githubusercontent.com/oskarwiese/fagprojekt/master/compas/compas-scores-raw.csv"
#url = "https://raw.githubusercontent.com/oskarwiese/fagprojekt/master/compas/cox-violent-parsed_filt.csv"
url = "https://raw.githubusercontent.com/oskarwiese/fagprojekt/master/compas/cox-violent-parsed.csv"
data = pd.read_csv(url)
# Til at se på dataen 
#print(data.head)
print(data.columns)
print(data.head)
print(data.head()['is_recid'])

use_cuda = torch.cuda.is_available()
print("Running GPU.") if use_cuda else print("No GPU available.")

print(data['score_text'])
# Out:
# Index(['id', 'name', 'first', 'last', 'compas_screening_date', 'sex', 'dob',
#        'age', 'age_cat', 'race', 'juv_fel_count', 'decile_score',
#        'juv_misd_count', 'juv_other_count', 'priors_count',
#        'days_b_screening_arrest', 'c_jail_in', 'c_jail_out', 'c_case_number',
#        'c_offense_date', 'c_arrest_date', 'c_days_from_compas',
#        'c_charge_degree', 'c_charge_desc', 'is_recid', 'r_case_number',
#        'r_charge_degree', 'r_days_from_arrest', 'r_offense_date',
#        'r_charge_desc', 'r_jail_in', 'r_jail_out', 'violent_recid',
#        'is_violent_recid', 'vr_case_number', 'vr_charge_degree',
#        'vr_offense_date', 'vr_charge_desc', 'type_of_assessment',
#        'decile_score.1', 'score_text', 'screening_date',
#        'v_type_of_assessment', 'v_decile_score', 'v_score_text',
#        'v_screening_date', 'in_custody', 'out_custody', 'priors_count.1',
#        'start', 'end', 'event'],
#       dtype='object')
# <bound method NDFrame.head of          id                   name        first         last  \
# 0       1.0       miguel hernandez       miguel    hernandez
# 1       2.0       miguel hernandez       miguel    hernandez
# 2       3.0           michael ryan      michael         ryan
# 3       4.0            kevon dixon        kevon        dixon
# 4       5.0               ed philo           ed        philo
# 5       6.0               ed philo           ed        philo
# 6       7.0               ed philo           ed        philo
# 7       8.0               ed philo           ed        philo
# 8       9.0               ed philo           ed        philo
# 9      10.0            marcu brown        marcu        brown
# 10     11.0     bouthy pierrelouis       bouthy  pierrelouis
# 11     12.0           marsha miles       marsha        miles
# 12     13.0          edward riddle       edward       riddle
# 13     14.0          edward riddle       edward       riddle
# 14     15.0         steven stewart       steven      stewart
# 15     16.0         steven stewart       steven      stewart
# 16     17.0         steven stewart       steven      stewart
# 17     18.0       elizabeth thieme    elizabeth       thieme
# 18     19.0      darrell blackburn      darrell    blackburn
# 19     20.0      darrell blackburn      darrell    blackburn
# 20     21.0      darrell blackburn      darrell    blackburn
# 21     22.0             jamie good        jamie         good
# 22     23.0             jamie good        jamie         good
# 23     24.0             jamie good        jamie         good
# 24     25.0              bo bradac           bo       bradac
# 25     26.0         benjamin franc     benjamin        franc
# 26     27.0         ellyaher lanza     ellyaher        lanza
# 27     28.0        kortney coleman      kortney      coleman
# 28     29.0             kyle lewis         kyle        lewis
# 29     30.0           jarrod turbe       jarrod        turbe
# ...     ...                    ...          ...          ...
# 18286   NaN       shantrina stfort    shantrina       stfort
# 18287   NaN            kyle miller         kyle       miller
# 18288   NaN            kyle miller         kyle       miller
# 18289   NaN            kyle miller         kyle       miller
# 18290   NaN            kyle miller         kyle       miller
# 18291   NaN            kyle miller         kyle       miller
# 18292   NaN            kyle miller         kyle       miller
# 18293   NaN        michelle greigg     michelle       greigg
# 18294   NaN           ceasar gomez       ceasar        gomez
# 18295   NaN           ceasar gomez       ceasar        gomez
# 18296   NaN         luis fernandez         luis    fernandez
# 18297   NaN      rodney montgomery       rodney   montgomery
# 18298   NaN        christopher tun  christopher          tun
# 18299   NaN        christopher tun  christopher          tun
# 18300   NaN        christopher tun  christopher          tun
# 18301   NaN         kevin mcdonald        kevin     mcdonald
# 18302   NaN         alexander vega    alexander         vega
# 18303   NaN      natalia rodriguez      natalia    rodriguez
# 18304   NaN           jarred payne       jarred        payne
# 18305   NaN           jarred payne       jarred        payne
# 18306   NaN           raheem smith       raheem        smith
# 18307   NaN           raheem smith       raheem        smith
# 18308   NaN           raheem smith       raheem        smith
# 18309   NaN          steven butler       steven       butler
# 18310   NaN        malcolm simmons      malcolm      simmons
# 18311   NaN  alexsandra beauchamps   alexsandra   beauchamps
# 18312   NaN        winston gregory      winston      gregory
# 18313   NaN            farrah jean       farrah         jean
# 18314   NaN    florencia sanmartin    florencia    sanmartin
# 18315   NaN    florencia sanmartin    florencia    sanmartin
#
#       compas_screening_date     sex         dob  age          age_cat  \
# 0                14/08/2013    Male  18/04/1947   69  Greater than 45
# 1                14/08/2013    Male  18/04/1947   69  Greater than 45
# 2                31/12/2014    Male  06/02/1985   31          25 - 45
# 3                27/01/2013    Male  22/01/1982   34          25 - 45
# 4                14/04/2013    Male  14/05/1991   24     Less than 25
# 5                14/04/2013    Male  14/05/1991   24     Less than 25
# 6                14/04/2013    Male  14/05/1991   24     Less than 25
# 7                14/04/2013    Male  14/05/1991   24     Less than 25
# 8                14/04/2013    Male  14/05/1991   24     Less than 25
# 9                13/01/2013    Male  21/01/1993   23     Less than 25
# 10               26/03/2013    Male  22/01/1973   43          25 - 45
# 11               30/11/2013    Male  22/08/1971   44          25 - 45
# 12               19/02/2014    Male  23/07/1974   41          25 - 45
# 13               19/02/2014    Male  23/07/1974   41          25 - 45
# 14               30/08/2013    Male  25/02/1973   43          25 - 45
# 15               30/08/2013    Male  25/02/1973   43          25 - 45
# 16               30/08/2013    Male  25/02/1973   43          25 - 45
# 17               16/03/2014  Female  03/06/1976   39          25 - 45
# 18               09/12/2013    Male  16/11/1995   20     Less than 25
# 19               09/12/2013    Male  16/11/1995   20     Less than 25
# 20               09/12/2013    Male  16/11/1995   20     Less than 25
# 21               05/09/2014  Female  23/04/1989   26          25 - 45
# 22               05/09/2014  Female  23/04/1989   26          25 - 45
# 16                Other  ...       Risk of Violence               3
# 17            Caucasian  ...       Risk of Violence               1
# 18            Caucasian  ...       Risk of Violence               9
# 19            Caucasian  ...       Risk of Violence               9
# 20            Caucasian  ...       Risk of Violence               9
# 21            Caucasian  ...       Risk of Violence               3
# 22            Caucasian  ...       Risk of Violence               3
# 23            Caucasian  ...       Risk of Violence               3
# 24            Caucasian  ...       Risk of Violence               5
# 25            Caucasian  ...       Risk of Violence               4
# 26     African-American  ...       Risk of Violence               4
# 27            Caucasian  ...       Risk of Violence               1
# 28            Caucasian  ...       Risk of Violence               5
# 29     African-American  ...       Risk of Violence               2
# ...                 ...  ...                    ...             ...
# 18286  African-American  ...       Risk of Violence               7
# 18287  African-American  ...       Risk of Violence               7
# 18288  African-American  ...       Risk of Violence               7
# 18289  African-American  ...       Risk of Violence               7
# 18290  African-American  ...       Risk of Violence               7
# 18291  African-American  ...       Risk of Violence               7
# 18292  African-American  ...       Risk of Violence               7
# 18293  African-American  ...       Risk of Violence               1
# 18294          Hispanic  ...       Risk of Violence               3
# 18295          Hispanic  ...       Risk of Violence               3
# 18296          Hispanic  ...       Risk of Violence               1
# 18297  African-American  ...       Risk of Violence               3
# 18298         Caucasian  ...       Risk of Violence               9
# 18299         Caucasian  ...       Risk of Violence               9
# 18300         Caucasian  ...       Risk of Violence               9
# 18301         Caucasian  ...       Risk of Violence               2
# 18302         Caucasian  ...       Risk of Violence               7
# 18303         Caucasian  ...       Risk of Violence               3
# 18304  African-American  ...       Risk of Violence               2
# 18305  African-American  ...       Risk of Violence               2
# 18306  African-American  ...       Risk of Violence               9
# 18307  African-American  ...       Risk of Violence               9
# 18308  African-American  ...       Risk of Violence               9
# 18309  African-American  ...       Risk of Violence               5
# 18310  African-American  ...       Risk of Violence               5
# 18311  African-American  ...       Risk of Violence               4
# 18312             Other  ...       Risk of Violence               1
# 18313  African-American  ...       Risk of Violence               2
# 18314          Hispanic  ...       Risk of Violence               4
# 18315          Hispanic  ...       Risk of Violence               4
#
#        v_score_text  v_screening_date  in_custody  out_custody priors_count.1  \
# 0               Low        14/08/2013  07/07/2014   14/07/2014              0
# 1               Low        14/08/2013  07/07/2014   14/07/2014              0
# 2               Low        31/12/2014  30/12/2014   03/01/2015              0
# 3               Low        27/01/2013  26/01/2013   05/02/2013              0
# 4               Low        14/04/2013  16/06/2013   16/06/2013              4
# 5               Low        14/04/2013  30/07/2013   08/11/2013              4
# 6               Low        14/04/2013  27/03/2014   02/05/2014              4
# 7               Low        14/04/2013  08/01/2016   09/01/2016              4
# 8               Low        14/04/2013  08/01/2016   09/01/2016              4
# 9            Medium        13/01/2013         NaN          NaN              1
# 10              Low        26/03/2013         NaN          NaN              2
# 11              Low        30/11/2013  30/11/2013   01/12/2013              0
# 12              Low        19/02/2014  31/03/2014   18/04/2014             14
# 13              Low        19/02/2014  31/03/2014   18/04/2014             14
# 14              Low        30/08/2013  22/05/2014   03/06/2014              3
# 9         0  1174     0
# 10        0  1102     0
# 11        1   853     0
# 12        5    40     0
# 13       58   772     0
# 14        0   265     0
# 15      277   424     0
# 16      428   945     0
# 17        2   747     0
# 18       32   240     0
# 19      844   484     0
# 20      497   844     0
# 21        0    54     0
# 22      126   252     0
# 23      266   574     0
# 24        0   428     1
# 25        0   857     0
# 26        4   911     0
# 27        1  1186     0
# 28        0   610     0
# 29        0   905     0
# ...     ...   ...   ...
# 18286     4   878     0
# 18287     9   398     0
# 18288   417   420     0
# 18289   430   540     0
# 18290   546   551     0
# 18291   561   607     0
# 18292   625   800     0
# 18293     1   502     0
# 18294   173   322     0
# 18295   333  1097     0
# 18296     0   887     0
# 18297     5   825     0
# 18298     0    52     0
# 18299    65   181     0
# 18300   219   537     1
# 18301     0   646     0
# 18302     2  1057     0
# 18303     1   504     0
# 18304     0   530     0
# 18305   530   692     0
# 18306     0   169     0
# 18307   189   500     0
# 18308   507   894     0
# 18309     1   860     0
# 18310     1   790     0
# 18311     9   459     0
# 18312     0   808     0
# 18313     0   754     0
# 18314     0   258     0
# 18315   258   641     0
#
# [18316 rows x 52 columns]>
# 0    0
# 1    0
# 2   -1
# 3    1
# 4    1
# Name: is_recid, dtype: int64
# No GPU available.
# 0           Low
# 1           Low
# 2        Medium
# 3           Low
# 4           Low
# 5           Low
# 6           Low
# 7           Low
# 8           Low
# 9          High
# 10          Low
# 11          Low
# 12       Medium
# 13       Medium
# 14          Low
# 15          Low
# 16          Low
# 17          Low
# 18         High
# 19         High
# 20         High
# 21       Medium
# 22       Medium
# 23       Medium
# 24          Low
# 25          Low
# 26       Medium
# 27          Low
# 28          Low
# 29          Low
#           ...
# 18286    Medium
# 18287      High
# 18288      High
# 18289      High
# 18290      High
# 18291      High
# 18292      High
# 18293       Low
# 18294       Low
# 18295       Low
# 18296       Low
# 18297       Low
# 18298      High
# 18299      High
# 18300      High
# 18301       Low
# 18302    Medium
# 18303    Medium
# 18304       Low
# 18305       Low
# 18306      High
# 18307      High
# 18308      High
# 18309    Medium
# 18310       Low
# 18311    Medium
# 18312       Low
# 18313       Low
# 18314       Low
# 18315       Low
# Name: score_text, Length: 18316, dtype: object

# %%
def plots():
    # Show distribution of different ethnicities and sexes
    chart = sb.countplot(x = "race", data = data)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
    chart.set(xlabel='Ethnicity', ylabel='Count')
    plt.show()
    
    chart = sb.countplot(x = "sex", data = data)
    chart.set(xlabel='Sex', ylabel='Count')
    plt.show()
    
    #sb.countplot(x = "Language", data = data)
    #plt.show()
    
    # Showing the distribution of the raw and decile values
    plt.xlabel("v_decile_score")
    plt.ylabel("Frequency")
    plt.title("Visualization of the values")
    plt.hist(data["v_decile_score"])
    plt.show()
    
    plt.xlabel("Decile value")
    plt.ylabel("Frequency")
    plt.title("Visualization of the decile values")
    plt.hist(data["decile_score"])
    plt.show()
    
    
    #sb.countplot(x = "RawScore", hue = "Ethnic_Code_Text", data = data)
    #plt.show()
    
    # Indication that some black people might get higher sentences that white people
    sb.countplot(x = "decile_score", hue = "race", data = data)
    plt.show()
    
    sb.countplot(x = "score_text", hue = "race", data = data)
    plt.show()
plots()

# %%
categoricals = [ "sex", "race",'juv_misd_count', 'juv_other_count', 'priors_count','is_recid','is_violent_recid',]
# Changing date of birth into age,as this should work better in a neural network
if s == 1:
    ages = [None] * len(data["dob"])
    for i in range(len(data["dob"])):
        ages[i] = 20 +(100 - int(data["dob"][i].split("/")[2]))
    data["dob"] = ages
    numericals = ["dob"]
    s+=1
else:
    pass

outputs = ["score_text"]
data = data.dropna(subset=['score_text'])
data[outputs] = data[outputs].replace('Low',0)
data[outputs] = data[outputs].replace('Medium',1)
data[outputs] = data[outputs].replace('High',1)
data[outputs] = data[outputs].astype("category")
#outputs = ["DecileScore"]
#data["DecileScore"] = data["DecileScore"].replace(-1, 0)
#data["DecileScore"] = data["DecileScore"].astype("category")
#print(data["DecileScore"].cat.categories)

for category in categoricals:
    data[category] = data[category].astype("category")
    
so = data[outputs]
print(data[outputs])
so.isna().sum()
# Out:
#       score_text
# 0              0
# 1              0
# 2              1
# 3              0
# 4              0
# 5              0
# 6              0
# 7              0
# 8              0
# 9              1
# 10             0
# 11             0
# 12             1
# 13             1
# 14             0
# 15             0
# 16             0
# 17             0
# 18             1
# 19             1
# 20             1
# 21             1
# 22             1
# 23             1
# 24             0
# 25             0
# 26             1
# 27             0
# 28             0
# 29             0
# ...          ...
# 18286          1
# 18287          1
# 18288          1
# 18289          1
# 18290          1
# 18291          1
# 18292          1
# 18293          0
# 18294          0
# 18295          0
# 18296          0
# 18297          0
# 18298          1
# 18299          1
# 18300          1
# 18301          0
# 18302          1
# 18303          1
# 18304          0
# 18305          0
# 18306          1
# 18307          1
# 18308          1
# 18309          1
# 18310          0
# 18311          1
# 18312          0
# 18313          0
# 18314          0
# 18315          0
#
# [18293 rows x 1 columns]
# score_text    0
# dtype: int64

# %%
# Preparing data for pytorch
Xcat = []
for i in range(len(categoricals)):
    Xcat.append(data[categoricals[i]].cat.codes.values)
Xcat = torch.tensor(Xcat , dtype = torch.int64).T
#Converting the numerical values to a tensor
Xnum = np.stack([data[col].values for col in numericals], 1)
Xnum = torch.tensor(Xnum, dtype=torch.float)

# Converting the output to tensor
y = torch.tensor(data[outputs].values).flatten()

# Calculation of embedding sizes for the categorical values in the format (unique categorical values, embedding size (dimension of encoding))
categorical_column_sizes = [len(data[column].cat.categories) for column in categoricals]
categorical_embedding_sizes = [(col_size, min(50, (col_size+1)//2)) for col_size in categorical_column_sizes]

# Train-test split
totalnumber = len(Xnum)
testnumber = int(totalnumber * 0.2)

Xcattrain = Xcat[:totalnumber - testnumber]
Xcattest = Xcat[totalnumber - testnumber:totalnumber]
Xnumtrain = Xnum[:totalnumber - testnumber]
Xnumtest = Xnum[totalnumber - testnumber:totalnumber]
ytrain = y[:totalnumber - testnumber]
ytest = y[totalnumber - testnumber:totalnumber]

# %% [markdown]
# # Neural Network

# %%
class Model(nn.Module):

    def __init__(self, embedding_size, num_numerical_cols, output_size, layers, p=0.4):
        super().__init__()
        self.all_embeddings = nn.ModuleList([nn.Embedding(ni, nf) for ni, nf in embedding_size])
        self.embedding_dropout = nn.Dropout(p)
        self.batch_norm_num = nn.BatchNorm1d(num_numerical_cols)

        all_layers = []
        num_categorical_cols = sum((nf for ni, nf in embedding_size))
        input_size = num_categorical_cols + num_numerical_cols

        for i in layers:
            all_layers.append(nn.Linear(input_size, i))
            all_layers.append(nn.ReLU(inplace=True))
            all_layers.append(nn.BatchNorm1d(i))
            all_layers.append(nn.Dropout(p))
            input_size = i

        all_layers.append(nn.Linear(layers[-1], output_size))

        self.layers = nn.Sequential(*all_layers)

    def forward(self, x_categorical, x_numerical):
        embeddings = []
        for i,e in enumerate(self.all_embeddings):
            embeddings.append(e(x_categorical[:,i]))
        x = torch.cat(embeddings, 1)
        x = self.embedding_dropout(x)

        x_numerical = self.batch_norm_num(x_numerical)
        x = torch.cat([x, x_numerical], 1)
        x = self.layers(x)
        return nn.functional.softmax(x, dim = -1 )

# %%
# Define and show the model
model = Model(categorical_embedding_sizes, 1, 2, [8,16,32,64,128], p=0.6)
if use_cuda:
    model.cuda()
print(model)
# Out:
# Model(
#   (all_embeddings): ModuleList(
#     (0): Embedding(2, 1)
#     (1): Embedding(6, 3)
#     (2): Embedding(10, 5)
#     (3): Embedding(11, 6)
#     (4): Embedding(12, 6)
#     (5): Embedding(39, 20)
#     (6): Embedding(3, 2)
#     (7): Embedding(2, 1)
#   )
#   (embedding_dropout): Dropout(p=0.6, inplace=False)
#   (batch_norm_num): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=45, out_features=8, bias=True)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.6, inplace=False)
#     (4): Linear(in_features=8, out_features=16, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.6, inplace=False)
#     (8): Linear(in_features=16, out_features=32, bias=True)
#     (9): ReLU(inplace=True)
#     (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Dropout(p=0.6, inplace=False)
#     (12): Linear(in_features=32, out_features=64, bias=True)
#     (13): ReLU(inplace=True)
#     (14): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (15): Dropout(p=0.6, inplace=False)
#     (16): Linear(in_features=64, out_features=128, bias=True)
#     (17): ReLU(inplace=True)
#     (18): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): Dropout(p=0.6, inplace=False)
#     (20): Linear(in_features=128, out_features=2, bias=True)
#   )
# )

# %%
# Loss function and optimization
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001 , weight_decay = 1e-6)

# %%
epochs = 300
aggregated_losses = []

# Initialize lists for training and validation
train_iter = []
train_loss, train_accs = [], []
valid_iter = []
valid_loss, valid_accs = [], []

model.train()
for i in range(epochs):
    i += 1
    y_pred = model(Xcattrain, Xnumtrain)
    single_loss = loss_function(y_pred, ytrain)
    aggregated_losses.append(single_loss)
    
    if i % 25 == 1:
        print(f'epoch: {i:3} loss: {single_loss.item():10.8f}')
    
    optimizer.zero_grad()
    single_loss.backward()
    optimizer.step()
    
print(f'epoch: {i:3} loss: {single_loss.item():10.10f}')
    


# Plot the loss over epocs
plt.plot(range(epochs), aggregated_losses)
plt.ylabel('Loss')
plt.xlabel('epoch');


# Predict on the test set
model.eval()
with torch.no_grad():
    y_val = model(Xcattest, Xnumtest)
    loss = loss_function(y_val, ytest)


y_val = np.argmax(y_val, axis=1)


print(confusion_matrix(ytest,y_val))
print(classification_report(ytest,y_val))
print(accuracy_score(ytest, y_val))
# Out:
# epoch:   1 loss: 0.70984304
# epoch:  26 loss: 0.69550622
# epoch:  51 loss: 0.68489593
# epoch:  76 loss: 0.67400920
# epoch: 101 loss: 0.65266865
# epoch: 126 loss: 0.62215990

# %% [markdown]
# # Random Forest

# %%
# Define the model and fit it to the data
forestModel = RandomForestClassifier(n_estimators = 53, max_depth = 14, max_features = "log2", criterion = "entropy")
forestModel.fit(Xcattrain, ytrain)

# Predict on the test set
forestPreds = forestModel.predict(Xcattest)
forestProbs = forestModel.predict_proba(Xcattest)[:, 1]

print("Times low scoretext is predicted: ", len(forestPreds[forestPreds == 0]))
print("Times medium scoretext is predicted: ", len(forestPreds[forestPreds == 1]))
print("Times high scoretext is predicted: ", len(forestPreds[forestPreds == 2]))

print("Accuracy of the random forest model: ", len(forestPreds[torch.tensor(forestPreds, dtype = torch.int64) == ytest]) / len(forestPreds))
# Out:
# Times low scoretext is predicted:  1868
# Times medium scoretext is predicted:  1790
# Times high scoretext is predicted:  0
# Accuracy of the random forest model:  0.6755057408419901

# %% [markdown]
# # Baysian Optimization

# %%
## define the domain of the considered parameters
n_estimators = tuple(np.arange(1,301,1, dtype= np.int))
# print(n_estimators)
max_depth = tuple(np.arange(1,110,1, dtype= np.int))
# max_features = ('log2', 'sqrt', None)
max_features = (0, 1)
# criterion = ('gini', 'entropy')
criterion = (0, 1)


# define the dictionary for GPyOpt
domain = [{'n_estimators': 'var_1',  'type': 'discrete',     'domain': n_estimators},
          {'max_depth': 'var_2',     'type': 'discrete',     'domain': max_depth},
          {'max_features': 'var_3',  'type': 'categorical',  'domain': max_features},
          {'criterion': 'var_4',     'type': 'categorical',  'domain': criterion}]


## we have to define the function we want to maximize --> validation accuracy, 
## note it should take a 2D ndarray but it is ok that it assumes only one point
## in this setting
def objective_function(x): 
    print(x)
    # we have to handle the categorical variables that is convert 0/1 to labels
    # log2/sqrt and gini/entropy
    
    param = x[0]
    
    if param[2] == 0:
        var_3 = "log2"
    else:
        var_3 = "sqrt"
    
    if param[3] == 0:
        var_4 = "gini"
    else:
        var_4 = "entropy"
        
        
#fit the model
    model = RandomForestClassifier(n_estimators = int(param[0]), criterion = var_4, max_depth = int(param[1]), max_features = var_3)
    model.fit(Xcattrain, ytrain)
    forestPreds = model.predict(Xcattest)
    accuracy = len(forestPreds[torch.tensor(forestPreds, dtype = torch.int64) == ytest]) / len(forestPreds)
    return accuracy


opt = GPyOpt.methods.BayesianOptimization(f = objective_function,   # function to optimize
                                              domain = domain,         # box-constrains of the problem
                                              acquisition_type = "EI",      # Select acquisition function MPI, EI, LCB
                                             )
opt.acquisition.exploration_weight=.1

opt.run_optimization(max_iter = 100) 


x_best = opt.X[np.argmin(opt.Y)]
print("The best parameters obtained: n_estimators=" + str(x_best[0]) + ", max_depth=" + str(x_best[1]) + ", max_features=" + str(
    x_best[2])  + ", criterion=" + str(
